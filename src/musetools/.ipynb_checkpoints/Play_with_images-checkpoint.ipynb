# %%
from scipy import ndimage

# %%
from scipy import misc
f = misc.face()
misc.imsave('face.png',f)

import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()
# Out:
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

# %%
face = misc.imread('face.png')
# Out:
# /home/ahmed/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
type(face)
# Out:
# numpy.ndarray

# %%
face.shape, face.dtype
# Out:
# ((768, 1024, 3), dtype('uint8'))

# %%
f = misc.face(gray=True)
plt.imshow(f, cmap=plt.cm.gray)

# %%
plt.imshow(f, cmap=plt.cm.gray, vmin=30, vmax=200)
plt.axis('off')
plt.show()
