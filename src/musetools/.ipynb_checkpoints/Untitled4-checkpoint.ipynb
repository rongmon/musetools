# %%
from astropy.io import ascii
import matplotlib.pyplot as plt

# %%
data = ascii.read('/home/ahmed/astro/spectra/spectrum_fe_114_230.dat')
wave = data['wave']
wrest = data['wrest']
flx = data['flx']
flx_er = data['flx_er']
flx_norm  = data['flx_norm']
flx_er_norm = data['flx_er_norm']
plt.step(wrest, flx)
plt.step(wrest, flx_er)

# %%
plt.step(wrest, flx_norm)
plt.step(wrest, flx_er_norm)
